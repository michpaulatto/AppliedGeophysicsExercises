# %% [markdown]
# # Full waveform inversion exercise
#
# Created by Michele Paulatto, Imperial College London
#
# https://github.com/michpaulatto/AppliedGeophysicsExercises
#
#
# Version 0.5 - 21.01.2021
#
# This exercise is distributed under a [GNU GPL 3.0 license](https://www.gnu.org/licenses/gpl-3.0.en.html).
#
# ![](https://www.gnu.org/graphics/gplv3-with-text-136x68.png)
#
# Developed for [Google Colab](https://colab.research.google.com/)
#
# In this exercise we look at a 2D example of full waveform inversion.
# For our example we use synthetic data generated in a computer generated velocity model. The Marmousi model was created in 1988 by the Institut Francais du Pétrole (IFP). The model is based on a real profile through the North Quenguela trough in the Kwanza basin (offshore Angola). The geometry and velocity model were created to produce complex seismic data which require advanced processing techniques to obtain a correct Earth image. Traditional traveltime tomography is not suited to recover the detailed velocity information conatined in the model.
# The Marmousi model has been used extensively for testing of new methods and approaches for Earth imaging, not restricted to waveform inversion.
#
# You will not be running the inversion in real time. This would be too time consuming and complex to set up for the whole class. Instead the inversion has been run in advance on Imperial College's HPC cluster. This took only a few minutes, using 2 nodes, each runnning 24 processes. Large 3D inversions can take several days to run and require hundreds of compute nodes.
#
# The waveform modelling and inversion is done using Fullwave3d, a code developed at Imperial College by the Fullwave group, led by Mike Warner (https://fullwave3d.github.io/).

# %% [markdown]
# #Environment setup
#
# We need to set up the Python environment before we start. If running the exercise on your local machine the setup would have to be modified. We need to install Anaconda (https://www.anaconda.com/) and use it to install SegyIO. Some of the operations in the setup are a bit advanced and are beyond the scope of this exercise. So just run the following two code cells and move on. This may take a couple of minutes so be patient. If running this Notebook on Google Colab you may get a warning that the Notebook was not authored by Google, click OK and continue.

# %%
# %%bash
# PYTHONPATH=""
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT &> setup.log
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX &>> setup.log
# echo "Miniconda installed"
# Out:
# Miniconda installed

# %%
# !conda install --channel defaults conda python=3.6 --yes &>> setup.log
# !conda update --channel defaults --all --yes &>> setup.log
print("Anaconda updated and set up")
import sys
sys.path
_ = (sys.path.append("/usr/local/lib/python3.6/site-packages"))

# !conda install segyio -c conda-forge --yes &>> setup.log
print("Segyio installed")
# Out:
# Anaconda updated and set up
# Segyio installed

# %% [markdown]
# # Import modules and download data
#
# Here we import the Python modules that we need for the exercise and we download the data from Figshare.

# %%
# Python modules
import segyio
import numpy as np
import matplotlib.pyplot as plt
import re
# Download data
# !wget https://ndownloader.figshare.com/files/26531138 -O data.gz
# !tar --strip-components=1 -xvf data.gz
# Compile read_vtr utility
# !gfortran read_vtr.f90 -o read_vtr
# Out:
# --2021-02-18 15:29:30--  https://ndownloader.figshare.com/files/26531138
# Resolving ndownloader.figshare.com (ndownloader.figshare.com)... 3.248.121.212, 34.250.216.184, 52.19.225.241, ...
# Connecting to ndownloader.figshare.com (ndownloader.figshare.com)|3.248.121.212|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/26531138/fwi_exercise_data.gz [following]
# --2021-02-18 15:29:31--  https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/26531138/fwi_exercise_data.gz
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.40.203
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.40.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155436909 (148M) [application/gzip]
# Saving to: ‘data.gz’
#
# data.gz             100%[===================>] 148.24M  21.0MB/s    in 7.9s
#
# 2021-02-18 15:29:39 (18.7 MB/s) - ‘data.gz’ saved [155436909/155436909]
#
# fwi_exercise_data/fw-000980-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000080-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000220-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/Marm2D-CP00020-Grad.vtr
# fwi_exercise_data/Marm2D-CP00020-InvVp-Update.sgy
# fwi_exercise_data/fw-000060-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000240-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001080-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/read_vtr
# fwi_exercise_data/bw-000800-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000280-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001220-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000640-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000140-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000700-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001220-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001120-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000780-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000980-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00060-InvVp-Update.sgy
# fwi_exercise_data/bw-001060-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-Runfile.key
# fwi_exercise_data/bw-001060-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000740-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000900-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001240-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000740-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000460-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000800-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001180-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000980-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000040-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000960-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000120-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000520-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000420-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000260-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000680-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000260-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000240-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000920-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000060-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000440-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000040-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000160-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000540-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001040-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000280-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000940-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-Synthetic.sgy
# fwi_exercise_data/fw-000300-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000240-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000960-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000500-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000160-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000760-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000960-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000660-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000460-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001160-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000880-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000240-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000780-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000400-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000440-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001100-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/Marm2D-RawSign.sgy
# fwi_exercise_data/bw-001160-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001040-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000780-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000920-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000500-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000620-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000060-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000840-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000580-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001100-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000680-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000520-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001080-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000500-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000500-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000740-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/Marm2D-CP00080-Grad.vtr
# fwi_exercise_data/bw-000100-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000340-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000320-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000380-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000600-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000160-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000340-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000080-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000760-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001020-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001000-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001080-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000540-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000380-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000740-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/Marm2D-CP00020-Vp.sgy
# fwi_exercise_data/fw-000800-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000660-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000300-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000460-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000980-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000180-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000260-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000460-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000040-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000960-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000720-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000180-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000820-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000200-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000680-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000100-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000780-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/compare_6_120.bin
# fwi_exercise_data/bw-000860-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000120-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000180-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000340-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000960-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000020-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000700-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000040-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001020-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000600-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001020-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001220-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/compare_6_01.bin
# fwi_exercise_data/bw-000780-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000820-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000440-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000160-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000960-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000300-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000640-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000760-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000900-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001040-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000100-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000700-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001180-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000820-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001100-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000220-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000660-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000020-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001240-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000620-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000260-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000920-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000620-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000680-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000080-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00001-InvVp-Update.sgy
# fwi_exercise_data/fw-000360-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000720-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00120-Grad.vtr
# fwi_exercise_data/fw-001000-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000080-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000520-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000620-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000320-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000680-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000600-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/compare_6_80.bin
# fwi_exercise_data/fw-001020-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/compare_6_20.bin
# fwi_exercise_data/bw-000120-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000240-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000920-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000720-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000840-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000160-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000520-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000320-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000340-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000020-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000700-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000400-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000360-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001080-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00120-InvVp-Update.sgy
# fwi_exercise_data/bw-000400-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001120-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000200-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000620-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/Marm2D-CP00001-Vp.sgy
# fwi_exercise_data/bw-000140-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000140-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000100-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/compare_6_60.bin
# fwi_exercise_data/bw-000840-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000200-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001060-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000940-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-001160-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001160-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000880-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000940-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001220-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000540-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000920-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000560-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001080-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000580-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000620-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001100-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001180-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001040-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000080-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000780-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/compare_6_40.bin
# fwi_exercise_data/bw-000600-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000480-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000180-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001140-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000660-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000860-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000680-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001000-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000560-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-TrueVp.sgy
# fwi_exercise_data/fw-001220-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000280-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000860-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000540-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000860-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000240-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000600-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001080-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000080-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000180-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000380-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001140-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001040-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00060-Grad.vtr
# fwi_exercise_data/fw-001060-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000900-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000400-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000640-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001000-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001000-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000640-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000640-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000280-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000560-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001160-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000340-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000880-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000120-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000760-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000900-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001240-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000640-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001140-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001220-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000520-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000720-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001200-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000800-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000060-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001020-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000760-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000900-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001240-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000820-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001200-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-001140-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000840-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000840-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001000-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-StartVp.sgy
# fwi_exercise_data/fw-000120-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000720-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000540-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000440-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000820-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000880-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000300-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000220-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000320-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000060-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000700-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001100-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001220-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001240-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-001120-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000720-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000440-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001180-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000100-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000800-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00100-InvVp-Update.sgy
# fwi_exercise_data/bw-000280-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000740-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000360-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001120-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00060-Vp.sgy
# fwi_exercise_data/fw-000600-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/Marm2D-CP00100-Grad.vtr
# fwi_exercise_data/bw-000780-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000660-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000480-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000020-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001040-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-001140-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00040-Grad.vtr
# fwi_exercise_data/bw-000300-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000600-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000420-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000700-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000140-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000400-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000060-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-001100-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000400-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000680-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000280-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00080-InvVp-Update.sgy
# fwi_exercise_data/bw-000320-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000100-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001120-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000380-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000980-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001180-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000860-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000340-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000200-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000960-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000620-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001200-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000120-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000380-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001060-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001100-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-001060-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000200-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000260-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001160-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000300-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000180-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001120-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000380-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000360-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000220-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000160-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000580-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000660-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000980-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000320-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000560-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000020-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001000-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001020-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000520-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000940-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001240-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000380-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000460-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001200-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000880-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000900-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000880-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000580-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000940-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001020-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000660-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000980-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000080-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000760-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001140-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000700-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000420-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000420-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000480-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000060-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000500-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000200-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000040-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000840-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/read_vtr.f90
# fwi_exercise_data/Marm2D-out.log
# fwi_exercise_data/bw-000360-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001200-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000220-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/compare_6_100.bin
# fwi_exercise_data/fw-000420-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00040-InvVp-Update.sgy
# fwi_exercise_data/fw-001040-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000720-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000740-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-001120-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000500-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00120-Vp.sgy
# fwi_exercise_data/fw-000320-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000240-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000020-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001200-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000020-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000480-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000860-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00001-Grad.vtr
# fwi_exercise_data/fw-000900-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-001140-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-001080-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000140-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-001180-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000440-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001160-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001240-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00080-Vp.sgy
# fwi_exercise_data/bw-001180-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000640-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000820-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000480-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000180-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000460-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000560-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/Marm2D-CP00100-Vp.sgy
# fwi_exercise_data/fw-000460-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000040-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000860-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000580-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-001060-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000540-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000480-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000420-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000580-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000760-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000260-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000920-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000740-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000300-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000880-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000440-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000480-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/bw-000140-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000920-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/Marm2D-CP00040-Vp.sgy
# fwi_exercise_data/bw-000420-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000040-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000360-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000160-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000400-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000840-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000940-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000340-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000560-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000800-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000500-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-000260-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000560-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000220-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000540-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000100-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/bw-000800-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000280-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000820-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000120-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/bw-000360-csref00006-iter00120fwd1.vtr
# fwi_exercise_data/fw-000140-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000220-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000520-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/fw-000940-csref00006-iter00020fwd1.vtr
# fwi_exercise_data/bw-000580-csref00006-iter00060fwd1.vtr
# fwi_exercise_data/fw-000200-csref00006-iter00001fwd1.vtr
# fwi_exercise_data/fw-001200-csref00006-iter00020fwd1.vtr
# bw-000020-csref00006-iter00001fwd1.vtr	bw-001200-csref00006-iter00060fwd1.vtr
# bw-000020-csref00006-iter00020fwd1.vtr	bw-001200-csref00006-iter00120fwd1.vtr
# bw-000020-csref00006-iter00060fwd1.vtr	bw-001220-csref00006-iter00001fwd1.vtr
# bw-000020-csref00006-iter00120fwd1.vtr	bw-001220-csref00006-iter00020fwd1.vtr
# bw-000040-csref00006-iter00001fwd1.vtr	bw-001220-csref00006-iter00060fwd1.vtr
# bw-000040-csref00006-iter00020fwd1.vtr	bw-001220-csref00006-iter00120fwd1.vtr
# bw-000040-csref00006-iter00060fwd1.vtr	bw-001240-csref00006-iter00001fwd1.vtr
# bw-000040-csref00006-iter00120fwd1.vtr	bw-001240-csref00006-iter00020fwd1.vtr
# bw-000060-csref00006-iter00001fwd1.vtr	bw-001240-csref00006-iter00060fwd1.vtr
# bw-000060-csref00006-iter00020fwd1.vtr	bw-001240-csref00006-iter00120fwd1.vtr
# bw-000060-csref00006-iter00060fwd1.vtr	compare_6_01.bin
# bw-000060-csref00006-iter00120fwd1.vtr	compare_6_100.bin
# bw-000080-csref00006-iter00001fwd1.vtr	compare_6_120.bin
# bw-000080-csref00006-iter00020fwd1.vtr	compare_6_20.bin
# bw-000080-csref00006-iter00060fwd1.vtr	compare_6_40.bin
# bw-000080-csref00006-iter00120fwd1.vtr	compare_6_60.bin
# bw-000100-csref00006-iter00001fwd1.vtr	compare_6_80.bin
# bw-000100-csref00006-iter00020fwd1.vtr	data.gz
# bw-000100-csref00006-iter00060fwd1.vtr	fw-000020-csref00006-iter00001fwd1.vtr
# bw-000100-csref00006-iter00120fwd1.vtr	fw-000020-csref00006-iter00020fwd1.vtr
# bw-000120-csref00006-iter00001fwd1.vtr	fw-000020-csref00006-iter00120fwd1.vtr
# bw-000120-csref00006-iter00020fwd1.vtr	fw-000040-csref00006-iter00001fwd1.vtr
# bw-000120-csref00006-iter00060fwd1.vtr	fw-000040-csref00006-iter00020fwd1.vtr
# bw-000120-csref00006-iter00120fwd1.vtr	fw-000040-csref00006-iter00120fwd1.vtr
# bw-000140-csref00006-iter00001fwd1.vtr	fw-000060-csref00006-iter00001fwd1.vtr
# bw-000140-csref00006-iter00020fwd1.vtr	fw-000060-csref00006-iter00020fwd1.vtr
# bw-000140-csref00006-iter00060fwd1.vtr	fw-000060-csref00006-iter00120fwd1.vtr
# bw-000140-csref00006-iter00120fwd1.vtr	fw-000080-csref00006-iter00001fwd1.vtr
# bw-000160-csref00006-iter00001fwd1.vtr	fw-000080-csref00006-iter00020fwd1.vtr
# bw-000160-csref00006-iter00020fwd1.vtr	fw-000080-csref00006-iter00120fwd1.vtr
# bw-000160-csref00006-iter00060fwd1.vtr	fw-000100-csref00006-iter00001fwd1.vtr
# bw-000160-csref00006-iter00120fwd1.vtr	fw-000100-csref00006-iter00020fwd1.vtr
# bw-000180-csref00006-iter00001fwd1.vtr	fw-000100-csref00006-iter00120fwd1.vtr
# bw-000180-csref00006-iter00020fwd1.vtr	fw-000120-csref00006-iter00001fwd1.vtr
# bw-000180-csref00006-iter00060fwd1.vtr	fw-000120-csref00006-iter00020fwd1.vtr
# bw-000180-csref00006-iter00120fwd1.vtr	fw-000120-csref00006-iter00120fwd1.vtr
# bw-000200-csref00006-iter00001fwd1.vtr	fw-000140-csref00006-iter00001fwd1.vtr
# bw-000200-csref00006-iter00020fwd1.vtr	fw-000140-csref00006-iter00020fwd1.vtr
# bw-000200-csref00006-iter00060fwd1.vtr	fw-000140-csref00006-iter00120fwd1.vtr
# bw-000200-csref00006-iter00120fwd1.vtr	fw-000160-csref00006-iter00001fwd1.vtr
# bw-000220-csref00006-iter00001fwd1.vtr	fw-000160-csref00006-iter00020fwd1.vtr
# bw-000220-csref00006-iter00020fwd1.vtr	fw-000160-csref00006-iter00120fwd1.vtr
# bw-000220-csref00006-iter00060fwd1.vtr	fw-000180-csref00006-iter00001fwd1.vtr
# bw-000220-csref00006-iter00120fwd1.vtr	fw-000180-csref00006-iter00020fwd1.vtr
# bw-000240-csref00006-iter00001fwd1.vtr	fw-000180-csref00006-iter00120fwd1.vtr
# bw-000240-csref00006-iter00020fwd1.vtr	fw-000200-csref00006-iter00001fwd1.vtr
# bw-000240-csref00006-iter00060fwd1.vtr	fw-000200-csref00006-iter00020fwd1.vtr
# bw-000240-csref00006-iter00120fwd1.vtr	fw-000200-csref00006-iter00120fwd1.vtr
# bw-000260-csref00006-iter00001fwd1.vtr	fw-000220-csref00006-iter00001fwd1.vtr
# bw-000260-csref00006-iter00020fwd1.vtr	fw-000220-csref00006-iter00020fwd1.vtr
# bw-000260-csref00006-iter00060fwd1.vtr	fw-000220-csref00006-iter00120fwd1.vtr
# bw-000260-csref00006-iter00120fwd1.vtr	fw-000240-csref00006-iter00001fwd1.vtr
# bw-000280-csref00006-iter00001fwd1.vtr	fw-000240-csref00006-iter00020fwd1.vtr
# bw-000280-csref00006-iter00020fwd1.vtr	fw-000240-csref00006-iter00120fwd1.vtr
# bw-000280-csref00006-iter00060fwd1.vtr	fw-000260-csref00006-iter00001fwd1.vtr
# bw-000280-csref00006-iter00120fwd1.vtr	fw-000260-csref00006-iter00020fwd1.vtr
# bw-000300-csref00006-iter00001fwd1.vtr	fw-000260-csref00006-iter00120fwd1.vtr
# bw-000300-csref00006-iter00020fwd1.vtr	fw-000280-csref00006-iter00001fwd1.vtr
# bw-000300-csref00006-iter00060fwd1.vtr	fw-000280-csref00006-iter00020fwd1.vtr
# bw-000300-csref00006-iter00120fwd1.vtr	fw-000280-csref00006-iter00120fwd1.vtr
# bw-000320-csref00006-iter00001fwd1.vtr	fw-000300-csref00006-iter00001fwd1.vtr
# bw-000320-csref00006-iter00020fwd1.vtr	fw-000300-csref00006-iter00020fwd1.vtr
# bw-000320-csref00006-iter00060fwd1.vtr	fw-000300-csref00006-iter00120fwd1.vtr
# bw-000320-csref00006-iter00120fwd1.vtr	fw-000320-csref00006-iter00001fwd1.vtr
# bw-000340-csref00006-iter00001fwd1.vtr	fw-000320-csref00006-iter00020fwd1.vtr
# bw-000340-csref00006-iter00020fwd1.vtr	fw-000320-csref00006-iter00120fwd1.vtr
# bw-000340-csref00006-iter00060fwd1.vtr	fw-000340-csref00006-iter00001fwd1.vtr
# bw-000340-csref00006-iter00120fwd1.vtr	fw-000340-csref00006-iter00020fwd1.vtr
# bw-000360-csref00006-iter00001fwd1.vtr	fw-000340-csref00006-iter00120fwd1.vtr
# bw-000360-csref00006-iter00020fwd1.vtr	fw-000360-csref00006-iter00001fwd1.vtr
# bw-000360-csref00006-iter00060fwd1.vtr	fw-000360-csref00006-iter00020fwd1.vtr
# bw-000360-csref00006-iter00120fwd1.vtr	fw-000360-csref00006-iter00120fwd1.vtr
# bw-000380-csref00006-iter00001fwd1.vtr	fw-000380-csref00006-iter00001fwd1.vtr
# bw-000380-csref00006-iter00020fwd1.vtr	fw-000380-csref00006-iter00020fwd1.vtr
# bw-000380-csref00006-iter00060fwd1.vtr	fw-000380-csref00006-iter00120fwd1.vtr
# bw-000380-csref00006-iter00120fwd1.vtr	fw-000400-csref00006-iter00001fwd1.vtr
# bw-000400-csref00006-iter00001fwd1.vtr	fw-000400-csref00006-iter00020fwd1.vtr
# bw-000400-csref00006-iter00020fwd1.vtr	fw-000400-csref00006-iter00120fwd1.vtr
# bw-000400-csref00006-iter00060fwd1.vtr	fw-000420-csref00006-iter00001fwd1.vtr
# bw-000400-csref00006-iter00120fwd1.vtr	fw-000420-csref00006-iter00020fwd1.vtr
# bw-000420-csref00006-iter00001fwd1.vtr	fw-000420-csref00006-iter00120fwd1.vtr
# bw-000420-csref00006-iter00020fwd1.vtr	fw-000440-csref00006-iter00001fwd1.vtr
# bw-000420-csref00006-iter00060fwd1.vtr	fw-000440-csref00006-iter00020fwd1.vtr
# bw-000420-csref00006-iter00120fwd1.vtr	fw-000440-csref00006-iter00120fwd1.vtr
# bw-000440-csref00006-iter00001fwd1.vtr	fw-000460-csref00006-iter00001fwd1.vtr
# bw-000440-csref00006-iter00020fwd1.vtr	fw-000460-csref00006-iter00020fwd1.vtr
# bw-000440-csref00006-iter00060fwd1.vtr	fw-000460-csref00006-iter00120fwd1.vtr
# bw-000440-csref00006-iter00120fwd1.vtr	fw-000480-csref00006-iter00001fwd1.vtr
# bw-000460-csref00006-iter00001fwd1.vtr	fw-000480-csref00006-iter00020fwd1.vtr
# bw-000460-csref00006-iter00020fwd1.vtr	fw-000480-csref00006-iter00120fwd1.vtr
# bw-000460-csref00006-iter00060fwd1.vtr	fw-000500-csref00006-iter00001fwd1.vtr
# bw-000460-csref00006-iter00120fwd1.vtr	fw-000500-csref00006-iter00020fwd1.vtr
# bw-000480-csref00006-iter00001fwd1.vtr	fw-000500-csref00006-iter00120fwd1.vtr
# bw-000480-csref00006-iter00020fwd1.vtr	fw-000520-csref00006-iter00001fwd1.vtr
# bw-000480-csref00006-iter00060fwd1.vtr	fw-000520-csref00006-iter00020fwd1.vtr
# bw-000480-csref00006-iter00120fwd1.vtr	fw-000520-csref00006-iter00120fwd1.vtr
# bw-000500-csref00006-iter00001fwd1.vtr	fw-000540-csref00006-iter00001fwd1.vtr
# bw-000500-csref00006-iter00020fwd1.vtr	fw-000540-csref00006-iter00020fwd1.vtr
# bw-000500-csref00006-iter00060fwd1.vtr	fw-000540-csref00006-iter00120fwd1.vtr
# bw-000500-csref00006-iter00120fwd1.vtr	fw-000560-csref00006-iter00001fwd1.vtr
# bw-000520-csref00006-iter00001fwd1.vtr	fw-000560-csref00006-iter00020fwd1.vtr
# bw-000520-csref00006-iter00020fwd1.vtr	fw-000560-csref00006-iter00120fwd1.vtr
# bw-000520-csref00006-iter00060fwd1.vtr	fw-000580-csref00006-iter00001fwd1.vtr
# bw-000520-csref00006-iter00120fwd1.vtr	fw-000580-csref00006-iter00020fwd1.vtr
# bw-000540-csref00006-iter00001fwd1.vtr	fw-000580-csref00006-iter00120fwd1.vtr
# bw-000540-csref00006-iter00020fwd1.vtr	fw-000600-csref00006-iter00001fwd1.vtr
# bw-000540-csref00006-iter00060fwd1.vtr	fw-000600-csref00006-iter00020fwd1.vtr
# bw-000540-csref00006-iter00120fwd1.vtr	fw-000600-csref00006-iter00120fwd1.vtr
# bw-000560-csref00006-iter00001fwd1.vtr	fw-000620-csref00006-iter00001fwd1.vtr
# bw-000560-csref00006-iter00020fwd1.vtr	fw-000620-csref00006-iter00020fwd1.vtr
# bw-000560-csref00006-iter00060fwd1.vtr	fw-000620-csref00006-iter00120fwd1.vtr
# bw-000560-csref00006-iter00120fwd1.vtr	fw-000640-csref00006-iter00001fwd1.vtr
# bw-000580-csref00006-iter00001fwd1.vtr	fw-000640-csref00006-iter00020fwd1.vtr
# bw-000580-csref00006-iter00020fwd1.vtr	fw-000640-csref00006-iter00120fwd1.vtr
# bw-000580-csref00006-iter00060fwd1.vtr	fw-000660-csref00006-iter00001fwd1.vtr
# bw-000580-csref00006-iter00120fwd1.vtr	fw-000660-csref00006-iter00020fwd1.vtr
# bw-000600-csref00006-iter00001fwd1.vtr	fw-000660-csref00006-iter00120fwd1.vtr
# bw-000600-csref00006-iter00020fwd1.vtr	fw-000680-csref00006-iter00001fwd1.vtr
# bw-000600-csref00006-iter00060fwd1.vtr	fw-000680-csref00006-iter00020fwd1.vtr
# bw-000600-csref00006-iter00120fwd1.vtr	fw-000680-csref00006-iter00120fwd1.vtr
# bw-000620-csref00006-iter00001fwd1.vtr	fw-000700-csref00006-iter00001fwd1.vtr
# bw-000620-csref00006-iter00020fwd1.vtr	fw-000700-csref00006-iter00020fwd1.vtr
# bw-000620-csref00006-iter00060fwd1.vtr	fw-000700-csref00006-iter00120fwd1.vtr
# bw-000620-csref00006-iter00120fwd1.vtr	fw-000720-csref00006-iter00001fwd1.vtr
# bw-000640-csref00006-iter00001fwd1.vtr	fw-000720-csref00006-iter00020fwd1.vtr
# bw-000640-csref00006-iter00020fwd1.vtr	fw-000720-csref00006-iter00120fwd1.vtr
# bw-000640-csref00006-iter00060fwd1.vtr	fw-000740-csref00006-iter00001fwd1.vtr
# bw-000640-csref00006-iter00120fwd1.vtr	fw-000740-csref00006-iter00020fwd1.vtr
# bw-000660-csref00006-iter00001fwd1.vtr	fw-000740-csref00006-iter00120fwd1.vtr
# bw-000660-csref00006-iter00020fwd1.vtr	fw-000760-csref00006-iter00001fwd1.vtr
# bw-000660-csref00006-iter00060fwd1.vtr	fw-000760-csref00006-iter00020fwd1.vtr
# bw-000660-csref00006-iter00120fwd1.vtr	fw-000760-csref00006-iter00120fwd1.vtr
# bw-000680-csref00006-iter00001fwd1.vtr	fw-000780-csref00006-iter00001fwd1.vtr
# bw-000680-csref00006-iter00020fwd1.vtr	fw-000780-csref00006-iter00020fwd1.vtr
# bw-000680-csref00006-iter00060fwd1.vtr	fw-000780-csref00006-iter00120fwd1.vtr
# bw-000680-csref00006-iter00120fwd1.vtr	fw-000800-csref00006-iter00001fwd1.vtr
# bw-000700-csref00006-iter00001fwd1.vtr	fw-000800-csref00006-iter00020fwd1.vtr
# bw-000700-csref00006-iter00020fwd1.vtr	fw-000800-csref00006-iter00120fwd1.vtr
# bw-000700-csref00006-iter00060fwd1.vtr	fw-000820-csref00006-iter00001fwd1.vtr
# bw-000700-csref00006-iter00120fwd1.vtr	fw-000820-csref00006-iter00020fwd1.vtr
# bw-000720-csref00006-iter00001fwd1.vtr	fw-000820-csref00006-iter00120fwd1.vtr
# bw-000720-csref00006-iter00020fwd1.vtr	fw-000840-csref00006-iter00001fwd1.vtr
# bw-000720-csref00006-iter00060fwd1.vtr	fw-000840-csref00006-iter00020fwd1.vtr
# bw-000720-csref00006-iter00120fwd1.vtr	fw-000840-csref00006-iter00120fwd1.vtr
# bw-000740-csref00006-iter00001fwd1.vtr	fw-000860-csref00006-iter00001fwd1.vtr
# bw-000740-csref00006-iter00020fwd1.vtr	fw-000860-csref00006-iter00020fwd1.vtr
# bw-000740-csref00006-iter00060fwd1.vtr	fw-000860-csref00006-iter00120fwd1.vtr
# bw-000740-csref00006-iter00120fwd1.vtr	fw-000880-csref00006-iter00001fwd1.vtr
# bw-000760-csref00006-iter00001fwd1.vtr	fw-000880-csref00006-iter00020fwd1.vtr
# bw-000760-csref00006-iter00020fwd1.vtr	fw-000880-csref00006-iter00120fwd1.vtr
# bw-000760-csref00006-iter00060fwd1.vtr	fw-000900-csref00006-iter00001fwd1.vtr
# bw-000760-csref00006-iter00120fwd1.vtr	fw-000900-csref00006-iter00020fwd1.vtr
# bw-000780-csref00006-iter00001fwd1.vtr	fw-000900-csref00006-iter00120fwd1.vtr
# bw-000780-csref00006-iter00020fwd1.vtr	fw-000920-csref00006-iter00001fwd1.vtr
# bw-000780-csref00006-iter00060fwd1.vtr	fw-000920-csref00006-iter00020fwd1.vtr
# bw-000780-csref00006-iter00120fwd1.vtr	fw-000920-csref00006-iter00120fwd1.vtr
# bw-000800-csref00006-iter00001fwd1.vtr	fw-000940-csref00006-iter00001fwd1.vtr
# bw-000800-csref00006-iter00020fwd1.vtr	fw-000940-csref00006-iter00020fwd1.vtr
# bw-000800-csref00006-iter00060fwd1.vtr	fw-000940-csref00006-iter00120fwd1.vtr
# bw-000800-csref00006-iter00120fwd1.vtr	fw-000960-csref00006-iter00001fwd1.vtr
# bw-000820-csref00006-iter00001fwd1.vtr	fw-000960-csref00006-iter00020fwd1.vtr
# bw-000820-csref00006-iter00020fwd1.vtr	fw-000960-csref00006-iter00120fwd1.vtr
# bw-000820-csref00006-iter00060fwd1.vtr	fw-000980-csref00006-iter00001fwd1.vtr
# bw-000820-csref00006-iter00120fwd1.vtr	fw-000980-csref00006-iter00020fwd1.vtr
# bw-000840-csref00006-iter00001fwd1.vtr	fw-000980-csref00006-iter00120fwd1.vtr
# bw-000840-csref00006-iter00020fwd1.vtr	fw-001000-csref00006-iter00001fwd1.vtr
# bw-000840-csref00006-iter00060fwd1.vtr	fw-001000-csref00006-iter00020fwd1.vtr
# bw-000840-csref00006-iter00120fwd1.vtr	fw-001000-csref00006-iter00120fwd1.vtr
# bw-000860-csref00006-iter00001fwd1.vtr	fw-001020-csref00006-iter00001fwd1.vtr
# bw-000860-csref00006-iter00020fwd1.vtr	fw-001020-csref00006-iter00020fwd1.vtr
# bw-000860-csref00006-iter00060fwd1.vtr	fw-001020-csref00006-iter00120fwd1.vtr
# bw-000860-csref00006-iter00120fwd1.vtr	fw-001040-csref00006-iter00001fwd1.vtr
# bw-000880-csref00006-iter00001fwd1.vtr	fw-001040-csref00006-iter00020fwd1.vtr
# bw-000880-csref00006-iter00020fwd1.vtr	fw-001040-csref00006-iter00120fwd1.vtr
# bw-000880-csref00006-iter00060fwd1.vtr	fw-001060-csref00006-iter00001fwd1.vtr
# bw-000880-csref00006-iter00120fwd1.vtr	fw-001060-csref00006-iter00020fwd1.vtr
# bw-000900-csref00006-iter00001fwd1.vtr	fw-001060-csref00006-iter00120fwd1.vtr
# bw-000900-csref00006-iter00020fwd1.vtr	fw-001080-csref00006-iter00001fwd1.vtr
# bw-000900-csref00006-iter00060fwd1.vtr	fw-001080-csref00006-iter00020fwd1.vtr
# bw-000900-csref00006-iter00120fwd1.vtr	fw-001080-csref00006-iter00120fwd1.vtr
# bw-000920-csref00006-iter00001fwd1.vtr	fw-001100-csref00006-iter00001fwd1.vtr
# bw-000920-csref00006-iter00020fwd1.vtr	fw-001100-csref00006-iter00020fwd1.vtr
# bw-000920-csref00006-iter00060fwd1.vtr	fw-001100-csref00006-iter00120fwd1.vtr
# bw-000920-csref00006-iter00120fwd1.vtr	fw-001120-csref00006-iter00001fwd1.vtr
# bw-000940-csref00006-iter00001fwd1.vtr	fw-001120-csref00006-iter00020fwd1.vtr
# bw-000940-csref00006-iter00020fwd1.vtr	fw-001120-csref00006-iter00120fwd1.vtr
# bw-000940-csref00006-iter00060fwd1.vtr	fw-001140-csref00006-iter00001fwd1.vtr
# bw-000940-csref00006-iter00120fwd1.vtr	fw-001140-csref00006-iter00020fwd1.vtr
# bw-000960-csref00006-iter00001fwd1.vtr	fw-001140-csref00006-iter00120fwd1.vtr
# bw-000960-csref00006-iter00020fwd1.vtr	fw-001160-csref00006-iter00001fwd1.vtr
# bw-000960-csref00006-iter00060fwd1.vtr	fw-001160-csref00006-iter00020fwd1.vtr
# bw-000960-csref00006-iter00120fwd1.vtr	fw-001160-csref00006-iter00120fwd1.vtr
# bw-000980-csref00006-iter00001fwd1.vtr	fw-001180-csref00006-iter00001fwd1.vtr
# bw-000980-csref00006-iter00020fwd1.vtr	fw-001180-csref00006-iter00020fwd1.vtr
# bw-000980-csref00006-iter00060fwd1.vtr	fw-001180-csref00006-iter00120fwd1.vtr
# bw-000980-csref00006-iter00120fwd1.vtr	fw-001200-csref00006-iter00001fwd1.vtr
# bw-001000-csref00006-iter00001fwd1.vtr	fw-001200-csref00006-iter00020fwd1.vtr
# bw-001000-csref00006-iter00020fwd1.vtr	fw-001200-csref00006-iter00120fwd1.vtr
# bw-001000-csref00006-iter00060fwd1.vtr	fw-001220-csref00006-iter00001fwd1.vtr
# bw-001000-csref00006-iter00120fwd1.vtr	fw-001220-csref00006-iter00020fwd1.vtr
# bw-001020-csref00006-iter00001fwd1.vtr	fw-001220-csref00006-iter00120fwd1.vtr
# bw-001020-csref00006-iter00020fwd1.vtr	fw-001240-csref00006-iter00001fwd1.vtr
# bw-001020-csref00006-iter00060fwd1.vtr	fw-001240-csref00006-iter00020fwd1.vtr
# bw-001020-csref00006-iter00120fwd1.vtr	fw-001240-csref00006-iter00120fwd1.vtr
# bw-001040-csref00006-iter00001fwd1.vtr	fwi_exercise_data
# bw-001040-csref00006-iter00020fwd1.vtr	Marm2D-CP00001-Grad.vtr
# bw-001040-csref00006-iter00060fwd1.vtr	Marm2D-CP00001-InvVp-Update.sgy
# bw-001040-csref00006-iter00120fwd1.vtr	Marm2D-CP00001-Vp.sgy
# bw-001060-csref00006-iter00001fwd1.vtr	Marm2D-CP00020-Grad.vtr
# bw-001060-csref00006-iter00020fwd1.vtr	Marm2D-CP00020-InvVp-Update.sgy
# bw-001060-csref00006-iter00060fwd1.vtr	Marm2D-CP00020-Vp.sgy
# bw-001060-csref00006-iter00120fwd1.vtr	Marm2D-CP00040-Grad.vtr
# bw-001080-csref00006-iter00001fwd1.vtr	Marm2D-CP00040-InvVp-Update.sgy
# bw-001080-csref00006-iter00020fwd1.vtr	Marm2D-CP00040-Vp.sgy
# bw-001080-csref00006-iter00060fwd1.vtr	Marm2D-CP00060-Grad.vtr
# bw-001080-csref00006-iter00120fwd1.vtr	Marm2D-CP00060-InvVp-Update.sgy
# bw-001100-csref00006-iter00001fwd1.vtr	Marm2D-CP00060-Vp.sgy
# bw-001100-csref00006-iter00020fwd1.vtr	Marm2D-CP00080-Grad.vtr
# bw-001100-csref00006-iter00060fwd1.vtr	Marm2D-CP00080-InvVp-Update.sgy
# bw-001100-csref00006-iter00120fwd1.vtr	Marm2D-CP00080-Vp.sgy
# bw-001120-csref00006-iter00001fwd1.vtr	Marm2D-CP00100-Grad.vtr
# bw-001120-csref00006-iter00020fwd1.vtr	Marm2D-CP00100-InvVp-Update.sgy
# bw-001120-csref00006-iter00060fwd1.vtr	Marm2D-CP00100-Vp.sgy
# bw-001120-csref00006-iter00120fwd1.vtr	Marm2D-CP00120-Grad.vtr
# bw-001140-csref00006-iter00001fwd1.vtr	Marm2D-CP00120-InvVp-Update.sgy
# bw-001140-csref00006-iter00020fwd1.vtr	Marm2D-CP00120-Vp.sgy
# bw-001140-csref00006-iter00060fwd1.vtr	Marm2D-out.log
# bw-001140-csref00006-iter00120fwd1.vtr	Marm2D-RawSign.sgy
# bw-001160-csref00006-iter00001fwd1.vtr	Marm2D-Runfile.key
# bw-001160-csref00006-iter00020fwd1.vtr	Marm2D-StartVp.sgy
# bw-001160-csref00006-iter00060fwd1.vtr	Marm2D-Synthetic.sgy
# bw-001160-csref00006-iter00120fwd1.vtr	Marm2D-TrueVp.sgy
# bw-001180-csref00006-iter00001fwd1.vtr	Miniconda3-4.5.4-Linux-x86_64.sh
# bw-001180-csref00006-iter00020fwd1.vtr	read_vtr
# bw-001180-csref00006-iter00060fwd1.vtr	read_vtr.f90
# bw-001180-csref00006-iter00120fwd1.vtr	sample_data
# bw-001200-csref00006-iter00001fwd1.vtr	setup.log
# bw-001200-csref00006-iter00020fwd1.vtr	tmp

# %% [markdown]
# # Experiment geometry
#
# here we read some parameters defining the experiment geometry

# %%
# Name of project
project='Marm2D'
# Read inversion and model parameters
runfile=project+'-Runfile.key'

# Open file and read parameters
with open(runfile) as f:
    text = f.readlines()
    for line in text:
        if 'NSHOT' in line: nshot = np.int(line.split(':')[-1])
        if 'NRECS' in line: nrecs = np.int(line.split(':')[-1])
        if 'NX1' in line: nx1 = np.int(line.split(':')[-1])
        if 'NX3' in line: nx3 = np.int(line.split(':')[-1])
        if 'DX' in line: dx = np.float(line.split('!')[0].split(':')[-1])

print("Number of sources:",nshot)
print("Number of receivers:",nrecs)
print("Number x nodes:",nx1)
print("Number z nodes:",nx3)
print("Grid spacing:",dx,"m")
# Out:
# Number of sources: 15
# Number of receivers: 371
# Number x nodes: 384
# Number z nodes: 136
# Grid spacing: 24.0 m

# %% [markdown]
# # Source wavelet
#
# This is the source time function. At each source location we inject a pressure perturbation.

# %%
# Read source wavelet
filename='Marm2D-RawSign.sgy'
with segyio.open(filename, ignore_geometry=True) as f:
    # Get basic attributes
    n_traces = f.tracecount
    sample_rate = segyio.tools.dt(f) / 1000
    n_samples = f.samples.size
    time = f.samples
    data = f.trace.raw[:]  # Get all data into memory (could cause on big files)
    trace=data[0]
# Plot source wavelet
    fig = plt.figure(figsize=(10, 2))
    ax = fig.add_subplot(111)
    ax.plot(time,trace)
    ax.set_xlim(0,1000)
    ax.set_ylim(np.min(trace),np.max(trace))
    ax.set_xlabel('Time(ms)')
    ax.set_ylabel('Amplitude')
    ax.set_title('Source wavelet')

# %% [markdown]
# # Plot the data
#
# We use synthetic data generated by solving the forward problem (the acoustic wave equation) in the true velocity model. We will call this the "field data" in the rest of the exercise but remember that it is not real data. This is similar to what we did in the travel time exercise, where our "data" was also generated through the true model.

# %%
# Data filename
filename='Marm2D-Synthetic.sgy'
# Open data file
with segyio.open(filename, ignore_geometry=True) as f:
    # Get basic attributes
    n_traces = f.tracecount
    sample_rate = segyio.tools.dt(f) / 1000
    n_samples = f.samples.size
    time = f.samples
    data = f.trace.raw[:]  # Get all data into memory (could cause on big files)
print(f'N Traces: {n_traces}, N Samples: {n_samples}, Sample rate: {sample_rate}ms')
# Select amplitude cutoff for plotting
clip_percentile = 99
vm = np.percentile(data, clip_percentile)
print(f'The {clip_percentile}th percentile is {vm:.0f}; the max amplitude is {data.max():.0f}')

# Select shot to plot
shot=6
trace1=nrecs*(shot-1)
trace2=nrecs*shot

# Plot shot gather
fig = plt.figure(figsize=(18, 8))
ax = fig.add_subplot(1, 1, 1)
extent = [1, nrecs, time[-1], time[0]]  # define extent
ax.imshow(data.T[:,trace1:trace2], cmap="RdBu", vmin=-vm, vmax=vm, aspect='auto',extent=extent)
ax.set_xlabel('Receiver number')
ax.set_ylabel('Time [ms]')
ax.set_title(f'Shot number {shot}')
# Out:
# N Traces: 5565, N Samples: 1250, Sample rate: 2.4ms
# The 99th percentile is 1; the max amplitude is 82
# Text(0.5, 1.0, 'Shot number 6')

# %% [markdown]
# # True model and starting model
#
# The true model is the Marmousi model. The starting model in this case is obtained by smoothing the true model and adding a small bias. In real cases the starting model may be generated by travel time tomography or from the stacking velocities from processing of reflection data.

# %%
filename='Marm2D-TrueVp.sgy'
with segyio.open(filename, ignore_geometry=True) as f:
    vptrue = f.trace.raw[:]  # Get all data into memory (could cause issues on big files)

filename='Marm2D-StartVp.sgy'
with segyio.open(filename, ignore_geometry=True) as f:
    depth = f.samples
    vpstart = f.trace.raw[:]  # Get all data into memory (could cause issues on big files)

#print(f'N Traces: {n_traces}, N Samples: {n_samples}, Sample rate: {sample_rate}ms')

fig = plt.figure(figsize=(12, 10))

ax1 = fig.add_subplot(2, 1, 1)
extent = [0, nrecs*dx, depth[-1], depth[0]]  # define extent
ax1.imshow(vptrue.T, cmap="plasma", vmin=1500, vmax=5000, aspect='auto',extent=extent)
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Z (m)')
ax1.set_title('True model')

ax2 = fig.add_subplot(2, 1, 2)
extent = [0, nrecs*dx, depth[-1], depth[0]]  # define extent
ax2.imshow(vpstart.T, cmap="plasma", vmin=1500, vmax=5000, aspect='auto',extent=extent)
ax2.set_xlabel('X (m)')
ax2.set_ylabel('Z (m)')
ax2.set_title('Starting model')

# Add color scale
# Out:
# Text(0.5, 1.0, 'Starting model')

# %% [markdown]
# # The wavefield
#
# The wavefield describes the pressure field generated by the source. Below we read and plot the wavefield for shot number 6 calculate in the starting model.

# %%
# %matplotlib inline
from IPython.display import clear_output
from time import sleep

xtratop=0
xtrabot=50
xtra1=50
nx3w=nx3+xtratop+xtrabot
nx1w=nx1+2*xtra1

extent = [0, nrecs*dx, time[-1], time[0]]  # define extent
timesteps=np.arange(20,800,20,dtype=int)
#timesteps=np.arange(1240,500,-20,dtype=int)

iteration=1
iterstr=str(iteration).zfill(5)
shotstr=str(shot).zfill(5)
xcorr=np.zeros((nx1,nx3))
for step in timesteps:
    fig = plt.figure(figsize=(12, 5))
    timestr=str(step).zfill(6)
    filename='fw-'+timestr+'-csref'+shotstr+'-iter'+iterstr+'fwd1.vtr'
    # !./read_vtr <<< {filename} >& tmp
    binfile=filename+".bin"
    fw=np.fromfile(binfile, dtype=np.float32)
    fw=np.reshape(fw,(nx1w,nx3w))
    fw=fw[xtra1:-xtra1,xtratop:-xtrabot]
    clear_output(wait=True)
    plt.imshow(fw.T, cmap="gray",vmin=-70,vmax=70,aspect='auto',extent=extent)
    plt.show()
    sleep(0.03)

# %% [markdown]
# # Data misfit (residuals)
#
# The wavefield is defined everywhere in the model. We are interested in the value fo the wavefield at the receivers, so we extract the wavefield at these locations. This gives us shot gathers that we can compare to the data. Below we plot the syntehtics, data and residuals. The residuals are simply calculated by subdtracting the data from the synthetics. Notice how the synthetics are much simpler and don't contain all the complicated reflections seen in the data.

# %%
ntraces=nrecs*3
x1=0
x2=371

for step in ["01"]:
    filename='compare_6_'+step+'.bin'
    traces=np.fromfile(filename, dtype=np.float32)
    traces=np.reshape(traces,(ntraces,n_samples))
    

    fig = plt.figure(figsize=(15, 5))
    ax1 = fig.add_subplot(1, 3, 1)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,x1:x2], cmap="seismic",vmin=-0.1,vmax=0.1,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (ms)')
    ax1.set_title('Synthetics')
    ax1 = fig.add_subplot(1, 3, 2)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,nrecs+x1:nrecs+x2], cmap="seismic",vmin=-0.1,vmax=0.1,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (m)')
    ax1.set_title('Data')
    ax1 = fig.add_subplot(1, 3, 3)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,2*nrecs+x1:2*nrecs+x2], cmap="seismic",vmin=-0.2,vmax=0.2,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (m)')
    ax1.set_title('Residuals')

# %% [markdown]
# # Trace comparison
#
# The mismatch between data and synthetics can also be seen by plotting one of the traces as a wiggle. Below we plot the data in balck and the synthetics in blue. Notice how the first couple of peaks are predicted reasonably well, this correpsonds to the refracted arrivals. The later arrivals are not present in the synthetics because there are no sharp boundaries to generate the reflections.

# %%
tracenum=180
datatrace=traces[nrecs+tracenum,:]
syntrace=traces[tracenum,:]

fig = plt.figure(figsize=(12, 3))
ax = fig.add_subplot(111)
ax.plot(time,datatrace,'black')
ax.plot(time,syntrace,'blue')

ax.set_xlim(0,2500)
ax.set_ylim(np.min(datatrace),np.max(datatrace))
ax.set_xlabel('Time(ms)')
ax.set_ylabel('Amplitude')
ax.set_title('Trace comparison')
# Out:
# Text(0.5, 1.0, 'Trace comparison')

# %% [markdown]
# # The residual wavefield
#
# To compute the gradient ob the objective function we need to first calculate the back-propagate residual wavefield. this consists of turning the receivers into sources and the residuals into source time functions.
#
# Notice how all othe receivers act as sources at the same time. This is done to save computational cost.

# %%
# %matplotlib inline
from IPython.display import clear_output
from time import sleep

xtratop=0
xtrabot=50
xtra1=50
nx3w=nx3+xtratop+xtrabot
nx1w=nx1+2*xtra1

extent = [0, nrecs*dx, time[-1], time[0]]  # define extent
timesteps=np.arange(1240,500,-20,dtype=int)

iteration=1
iterstr=str(iteration).zfill(5)
shotstr=str(shot).zfill(5)
xcorr=np.zeros((nx1,nx3))
for step in timesteps:
    fig = plt.figure(figsize=(12, 5))
    timestr=str(step).zfill(6)
    filename='bw-'+timestr+'-csref'+shotstr+'-iter'+iterstr+'fwd1.vtr'
    # !./read_vtr <<< {filename} >& tmp
    binfile=filename+".bin"
    bw=np.fromfile(binfile, dtype=np.float32)
    bw=np.reshape(bw,(nx1w,nx3w))
    bw=bw[xtra1:-xtra1,xtratop:-xtrabot]
    clear_output(wait=True)
    plt.imshow(bw.T, cmap="gray",vmin=-0.1,vmax=0.1,aspect='auto',extent=extent)
    plt.show()
    sleep(0.03)

# %% [markdown]
# # Cross-correlation
#
# The cross-correlation consists in multiply the forward and residual wavefields at each time step and the summing al the timesteps together. First we look at the product of the forward and residual fields:

# %%
# %matplotlib inline
from IPython.display import clear_output
from time import sleep

xtratop=0
xtrabot=50
xtra1=50
nx3w=nx3+xtratop+xtrabot
nx1w=nx1+2*xtra1

extent = [0, nrecs*dx, time[-1], time[0]]  # define extent
timesteps=np.arange(20,880,20,dtype=int)
#timesteps=np.arange(1240,500,-20,dtype=int)

iteration=1
iterstr=str(iteration).zfill(5)
shotstr=str(shot).zfill(5)
xcorr=np.zeros((nx1,nx3))
for step in timesteps:
    fig = plt.figure(figsize=(12, 5))
    timestr=str(step).zfill(6)
    filename='fw-'+timestr+'-csref'+shotstr+'-iter'+iterstr+'fwd1.vtr'
    # !./read_vtr <<< {filename} >& tmp
    binfile=filename+".bin"
    fw=np.fromfile(binfile, dtype=np.float32)
    fw=np.reshape(fw,(nx1w,nx3w))
    fw=fw[xtra1:-xtra1,xtratop:-xtrabot]
    filename='bw-'+timestr+'-csref'+shotstr+'-iter'+iterstr+'fwd1.vtr'
    # !./read_vtr <<< {filename} >& tmp
    binfile=filename+".bin"
    bw=np.fromfile(binfile, dtype=np.float32)
    bw=np.reshape(bw,(nx1w,nx3w))
    bw=bw[xtra1:-xtra1,xtratop:-xtrabot]
    prod=bw*fw
    xcorr+=prod
    clear_output(wait=True)
    plt.imshow(prod.T, cmap="gray",vmin=-1,vmax=1,aspect='auto',extent=extent)
    plt.show()
    sleep(0.03)

# %% [markdown]
# Here we look at the summed contribution of all time steps for on of the sources

# %%
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 1, 1)
extent = [0, nrecs*dx, time[-1], time[0]]  # define extent
plt.imshow(xcorr.T, cmap="seismic",aspect='auto',extent=extent)

# %% [markdown]
# # The gradient
#
# If we sum together the contributions of all sources we get the gradient or the unscaled model update.

# %%
iteration=1
iterstr=str(iteration).zfill(5)
filename='Marm2D-CP'+iterstr+'-Grad.vtr'
# !./read_vtr <<< {filename} >& tmp

xtratop=1
xtrabot=50
xtra1=50
nx3w=nx3+xtratop+xtrabot
nx1w=nx1+2*xtra1

binfile=filename+".bin"
grad=np.fromfile(binfile, dtype=np.float32)
grad=np.reshape(grad,(nx1w,nx3w))
grad=grad[xtra1:-xtra1,xtratop:-xtrabot]

print(np.max(grad))

fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(1, 1, 1)
extent = [0, nrecs*dx, time[-1], time[0]]  # define extent
ax1.imshow(grad.T, cmap="seismic",aspect='auto',extent=extent)
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Z (m)')
ax1.set_title('Gradient')
# Out:
# 0.089824155
# Text(0.5, 1.0, 'Gradient')

# %% [markdown]
# # The step length
#
# After we calculate the gradient we can add a small perturbation to the starting model in the direction of the gradient. We then solve the forward problem one more time (recalculate the synthetic data) and recomputer the residuals. This helps us determine then step length, i.e. the optimal magnitude of the model update.
#
# Once we have the step length we can update the model.

# %%
iteration=1
iterstr=str(iteration).zfill(5)
filename='Marm2D-CP'+iterstr+'-InvVp-Update.sgy'
# Read the slowness update
with segyio.open(filename, ignore_geometry=True) as f:
    slowupdate = f.trace.raw[:] 
    depth = f.samples
filename='Marm2D-CP'+iterstr+'-Vp.sgy'

# Read Vp the model
with segyio.open(filename, ignore_geometry=True) as f:
    vp = f.trace.raw[:] 
    depth = f.samples
# Calculate the Vp update
vpupdate=slowupdate*vp*vp
    
fig = plt.figure(figsize=(14, 5))
ax1 = fig.add_subplot(1, 1, 1)
extent = [0, nrecs*dx, depth[-1], depth[0]]  # define extent
im=ax1.imshow(vpupdate.T, cmap="plasma", aspect='auto',extent=extent)
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Z (m)')
ax1.set_title('Model update')
fig.colorbar(im)

# %% [markdown]
# # Iteration procedure
#
# Once we have updated the model we can iterate. In this case we have run 120 iterations. These are divided into blocks of 20 iterations. In each block we have increased the frequency of the signal that we allow, starting only with low frequencies. This ensures that we avoid cycle skipping and falling into local minima.

# %% [markdown]
# # Output velocity models
#
# We can then have a look at how the starting model has changed. The box below will plot a comparison of the true model and output model. You can change the variable iternum to plot the output model for different steps (choose for example iterations 20, 40, 60, 80, 100, 120.

# %%
iternum=1

filename='Marm2D-TrueVp.sgy'
with segyio.open(filename, ignore_geometry=True) as f:
    vptrue = f.trace.raw[:]  # Get all data into memory (could cause issues on big files)

iterstr=str(iternum).zfill(5)
filename='Marm2D-CP'+iterstr+'-Vp.sgy'
with segyio.open(filename, ignore_geometry=True) as f:
    # Get basic attributes
    depth = f.samples
    vpstart = f.trace.raw[:]  # Get all data into memory (could cause issues on big files)

fig = plt.figure(figsize=(12, 10))

ax1 = fig.add_subplot(2, 1, 1)
extent = [0, nrecs*dx, depth[-1], depth[0]]  # define extent
ax1.imshow(vptrue.T, cmap="plasma", vmin=1500, vmax=5000, aspect='auto',extent=extent)
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Z (m)')
ax1.set_title('True model')

ax2 = fig.add_subplot(2, 1, 2)
extent = [0, nrecs*dx, depth[-1], depth[0]]  # define extent
ax2.imshow(vpstart.T, cmap="plasma", vmin=1500, vmax=5000, aspect='auto',extent=extent)
ax2.set_xlabel('X (m)')
ax2.set_ylabel('Z (m)')
ax2.set_title('Iteration '+iterstr)
# Out:
# Text(0.5, 1.0, 'Iteration 00001')

# %% [markdown]
# # Data match
#
# Here we look at how the data match has improved throughout the inversion. We plot the syntehtics, data and residuals for iteration 1, 20, 60 and 120. notice how by iteration 20 we can already predict the data very well. Subsequent iterations add higher frequency content and fit the smaller scale structure.

# %%
ntraces=nrecs*3
x1=0
x2=370
ampmin=-0.2
ampmax=0.2
for step in ["01","20","60","120"]:
    filename='compare_6_'+step+'.bin'
    traces=np.fromfile(filename, dtype=np.float32)
    traces=np.reshape(traces,(ntraces,n_samples))
    

    fig = plt.figure(figsize=(15, 5))
    ax1 = fig.add_subplot(1, 3, 1)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,x1:x2], cmap="seismic",vmin=ampmin,vmax=ampmax,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (ms)')
    ax1.set_title('Synthetics')
    ax1 = fig.add_subplot(1, 3, 2)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,nrecs+x1:nrecs+x2], cmap="seismic",vmin=ampmin,vmax=ampmax,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (m)')
    ax1.set_title('Data')
    ax1 = fig.add_subplot(1, 3, 3)
    extent = [x1, x2*dx, time[-1], time[0]]  # define extent
    ax1.imshow(traces.T[:,2*nrecs+x1:2*nrecs+x2], cmap="seismic",vmin=ampmin,vmax=ampmax,aspect='auto',extent=extent)
    ax1.set_xlabel('X (m)')
    ax1.set_ylabel('t (m)')
    ax1.set_title('Residuals')

# %% [markdown]
# # Trace match
#
# As a last check we look at how the trace match has improved. Notice that the final traces contain higher frequency because we have gradually increased the bandwidth of the the data and source as we progressed in the inversion.

# %%
finaldatatrace=traces[nrecs+tracenum,:]
finalsyntrace=traces[tracenum,:]

fig = plt.figure(figsize=(12,7))
ax1 = fig.add_subplot(211)
ax1.plot(time,datatrace,'black')
ax1.plot(time,syntrace,'blue')
ax1.set_xlim(0,2500)
ax1.set_ylim(np.min(datatrace),np.max(datatrace))
ax1.set_ylabel('Amplitude')
ax1.set_title('Initial trace comparison')

ax2 = fig.add_subplot(212)
ax2.plot(time,finaldatatrace,'black',":")
ax2.plot(time,finalsyntrace,'blue',":")
ax2.set_xlim(0,2500)
ax2.set_ylim(np.min(datatrace),np.max(datatrace))
ax2.set_ylabel('Amplitude')
ax2.set_title('Final trace comparison')
ax2.set_xlabel('Time(ms)')
# Out:
# Text(0.5, 0, 'Time(ms)')

# %% [markdown]
# # Final considerations
